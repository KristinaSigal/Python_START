# %%
from sympy import *
from sympy.plotting import plot

# %%
x=Symbol('x')
f=x**3-50*x
g= -x**4 + 88*x**2 - 241
d = f-g
for i in solve(d):
    print(f"x: {i.evalf()} y: {d.subs(x, i).evalf()}")
# Out:
# x: -9.45940430667182 - 1.18047371141687e-27*I y: -0.e-126 - 0.e-136*I
# x: 1.41817900669911 + 1.18047371141683e-27*I y: 0.e-130 - 0.e-137*I
# x: -1.98933342984912 - 1.18047371141326e-27*I y: 0.e-133 + 0.e-139*I
# x: 9.03055872982183 + 1.1804737114133e-27*I y: -0.e-125 - 0.e-133*I

# %%
plot(f, g)

# %%
plot(d)

# %%
#
